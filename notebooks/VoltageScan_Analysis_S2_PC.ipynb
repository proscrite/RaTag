# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from glob import glob
from RaTag.scripts.wfm2read_fast import wfm2read # type: ignore
from RaTag.scripts.wfm_sca_trigger import moving_average # type: ignore
from scipy.signal import find_peaks
from scipy import sparse
from scipy.sparse.linalg import spsolve

# Recommended rcParams for larger font sizes
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.rcParams['legend.fontsize'] = 14
plt.rcParams['axes.titlesize'] = 18

# %%
def integrate_s2(file, s2_lowcut=0.5e-5, s2_upcut=1.5e-5):
    wf = wfm2read(file)
    t, V = wf[1], -wf[0]
    
    bs_lowcut = 2e-5
    bs_upcut = 4e-5
    baseline_window = (t > bs_lowcut) & (t < bs_upcut)
    baseline = np.mean(V[baseline_window])
    V -= baseline

    s2_window = (t > s2_lowcut) & (t < s2_upcut)
    area_s2 = np.trapz(V[s2_window], t[s2_window]) * 1e6 / 1e-3  # Convert to milivolts / microsec
    return area_s2, V, t

def plot_s2_integration(t, V, s2_lowcut, s2_upcut, trig_x = None, trig_y = None):

    plt.plot(t, V, label='SCA Waveform')
    if trig_x is not None and trig_y is not None:
        plt.plot(trig_x, trig_y, label='Trigger SCA', color='orange')

    plt.fill_betweenx(
        [0, 1],
        x1=s2_lowcut,
        x2=s2_upcut,
        color='green',
        alpha=0.3,
        label='S2 window'
    )
    plt.gca().set(xlabel='Time (s)', ylabel='Voltage (V)', title='SCA Waveform with Trigger')

def extract_s2_areas(files):
    areas = []
    for f in files:
        as2, V, t = integrate_s2(f)
        areas.append(as2)
    return np.array(areas)

def apply_hist_cuts(arr, lowcut, upcut):
    return arr[(arr > lowcut) & (arr < upcut)]

# %% [markdown]
# # Anode voltage scan
# Gate fixed at 700 V

# %%
trigger_file = r'E:\Pablos_Mighty_measurements\RUN1\GasCirculation_5GSsec_TriggerSCA_EL2100V\sca_waveform.wfm'
trig = wfm2read(trigger_file, verbose=False)
trig_x, trig_y = trig[1], trig[0]
trig_y = trig_y / (10 * np.max(trig_y))

# Define voltage values for scan
voltages_el = ['2100', '2600', '3100', '3600']

# Build paths and file lists using a loop
base_path_el = r'E:\Pablos_Mighty_measurements\RUN1\VoltageScans\VoltageScan_1GSsec_EL{}_Gate700\\*.wfm'
voltage_files_el = {}
for v in voltages_el:
    path = base_path_el.format(v)
    files = sorted(glob(path))
    voltage_files_el[v] = files
    print(f"Voltage {v}V: {len(files)} files")

# For compatibility with previous cells, you can still assign:
files21 = voltage_files_el['2100']
files26 = voltage_files_el['2600']
files31 = voltage_files_el['3100']
files36 = voltage_files_el['3600']
# Out:
# Voltage 2100V: 3000 files
# Voltage 2600V: 3000 files
# Voltage 3100V: 3000 files
# Voltage 3600V: 3000 files

# %%
# Define voltage scan groups and their file lists
voltage_groups_el = {
    '2100': files21,
    '2600': files26,
    '3100': files31,
    '3600': files36
}

s2_lowcut = 0.5e-5
s2_upcut = 1.5e-5
hist_lowcut = -10
hist_upcut = 20


# Process all voltage groups
s2_areas_el = {}
s2_areas_cuts_el = {}
for v, files in voltage_groups_el.items():
    arr = extract_s2_areas(files)
    s2_areas_el[v] = arr
    s2_areas_cuts_el[v] = apply_hist_cuts(arr, hist_lowcut, hist_upcut)

# %%
plt.figure(figsize=(8, 6))
for v, label, color in zip(['2100', '2600', '3100', '3600'],
                              ['Anode 2.1 kV', 'Anode 2.6 kV', 'Anode 3.1 kV', 'Anode 3.6 kV'],
                              ['blue', 'orange', 'green', 'red']):
    plt.hist(s2_areas_cuts_el[v], bins=150, alpha=0.5, label=label, color=color)

plt.gca().set(xlabel='S2 Area (mV*us)', ylabel='Counts', title='Anode scan, Gate at 700 V')
plt.legend()

# %%
plt.figure(figsize=(8, 6))
plt.hist(s2_areas_cuts_el['3100'], bins=150, alpha=0.5, label='Anode 3.1 kV', color='green');
plt.gca().set(xlabel='S2 Area (mV*us)', ylabel='Counts', title='Gate Voltage scan, Anode 3.1 kV');
plt.legend()

# %%
plt.figure(figsize=(8, 6))
for f in files21[:50]:
    wf = wfm2read(f)
    y, t = -wf[0], wf[1]
    plt.plot(t, y, alpha=0.5)

plt.plot(trig_x, trig_y, label='Trigger SCA', color='black')
plt.fill_betweenx(
        [0, 0.1],
        x1=s2_lowcut, x2=s2_upcut,
        color='green', alpha=0.3, label='S2 window'
    )

s1_lowcut = -0.4e-5
s1_upcut = -0.25e-5
plt.fill_betweenx(
        [0, 0.1],
        x1=s1_lowcut, x2=s1_upcut,
        color='blue', alpha=0.3, label='S1 window'
    )


plt.gca().set(xlim=(-1e-5, 2.2e-5), xlabel='t (s)', ylabel='Amplitude (V)')
plt.legend()
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='x', scilimits=(-6, -6))
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Gate voltage scan:
# Anode fixed at 3100 V

# %%
trigger_file = r'E:\Pablos_Mighty_measurements\RUN1\GasCirculation_5GSsec_TriggerSCA_EL2100V\sca_waveform.wfm'
trig = wfm2read(trigger_file, verbose=False)
trig_x, trig_y = trig[1], trig[0]
trig_y = trig_y / (10 * np.max(trig_y))

# Define voltage values for scan
voltages = ['700', '1200', '1700', '2200', '2700']

# Build paths and file lists using a loop
base_path = r'E:\Pablos_Mighty_measurements\RUN1\VoltageScans\VoltageScan_1GSsec_EL3100_Gate{}\\*.wfm'
voltage_files = {}
for v in voltages:
    path = base_path.format(v)
    files = sorted(glob(path))
    voltage_files[v] = files
    print(f"Voltage {v}V: {len(files)} files")

# For compatibility with previous cells, you can still assign:
files07 = voltage_files['700']
files12 = voltage_files['1200']
files17 = voltage_files['1700']
files22 = voltage_files['2200']
files27 = voltage_files['2700']
# Out:
# Voltage 700V: 3000 files
# Voltage 1200V: 3000 files
# Voltage 1700V: 3000 files
# Voltage 2200V: 3000 files
# Voltage 2700V: 3000 files

# %%
# Define voltage scan groups and their file lists
voltage_groups = {
    '700': files07,
    '1200': files12,
    '1700': files17,
    '2200': files22,
    '2700': files27
}

s2_lowcut = 0.5e-5
s2_upcut = 1.5e-5
hist_lowcut = -5
hist_upcut = 20


# Process all voltage groups
s2_areas = {}
s2_areas_cuts = {}
for v, files in voltage_groups.items():
    arr = extract_s2_areas(files)
    s2_areas[v] = arr
    s2_areas_cuts[v] = apply_hist_cuts(arr, hist_lowcut, hist_upcut)

# %%
plt.figure(figsize=(8, 6))
for v, label, color in zip(['2700', '2200', '1700', '1200', '700'],
                              ['Gate 2.7 kV', 'Gate 2.2 kV', 'Gate 1.7 kV', 'Gate 1.2 kV', 'Gate 0.7 kV'],
                              ['blue', 'orange', 'green', 'red', 'purple']):
    plt.hist(s2_areas_cuts[v], bins=150, alpha=0.5, label=label, color=color)

plt.gca().set(xlabel='S2 Area (mV*us)', ylabel='Counts', title='Gate Voltage scan, Anode 3.1 kV')
plt.legend()

# %%
plt.figure(figsize=(8, 6))
for v, label, color in zip(['2700', '2200', '1700', '1200', '700'],
                              ['Gate 2.7 kV', 'Gate 2.2 kV', 'Gate 1.7 kV', 'Gate 1.2 kV', 'Gate 0.7 kV'],
                              ['blue', 'orange', 'green', 'red', 'purple']):
    plt.hist(s2_areas[v], bins=100, alpha=0.5, label=label, color=color)

plt.gca().set(xlabel='S2 Area (mV*us)', ylabel='Counts', xlim=(-1000, 1000),
               title='Gate Voltage scan, Anode 3.1 kV')
plt.legend()

# %% [markdown]
# # Drift Field scan:
# Vary both voltages together, then the EL field stays constant (difference of 1400 V) and the drift field increases

# %%
trigger_file = r'E:\Pablos_Mighty_measurements\RUN1\GasCirculation_5GSsec_TriggerSCA_EL2100V\sca_waveform.wfm'
trig = wfm2read(trigger_file, verbose=False)
trig_x, trig_y = trig[1], trig[0]
trig_y = trig_y / (10 * np.max(trig_y))

# %%
# Define voltage values for scan
voltage_pairs = [(2100, 700), (2600, 1200), (3100, 1700), (3600, 2200), (4100, 2700)]
# Build paths and file lists using a loop
base_path_el = r'E:\Pablos_Mighty_measurements\RUN1\FieldScans_sat\FieldScan_1GSsec_EL{}_Gate{}\*.wfm'
field_files = {}
for v in voltage_pairs:
    path = base_path_el.format(str(v[0]), str(v[1]))
    print(path)
    files = sorted(glob(path))
    field_files[v] = files
    print(f"Voltage {v}V: {len(files)} files")

# For compatibility with previous cells, you can still assign:
files21 = field_files[(2100, 700)]
files26 = field_files[(2600, 1200)]
files31 = field_files[(3100, 1700)]
files36 = field_files[(3600, 2200)]
files41 = field_files[(4100, 2700)]
# Out:
# E:\Pablos_Mighty_measurements\RUN1\FieldScans_sat\FieldScan_1GSsec_EL2100_Gate700\*.wfm
# Voltage (2100, 700)V: 3000 files
# E:\Pablos_Mighty_measurements\RUN1\FieldScans_sat\FieldScan_1GSsec_EL2600_Gate1200\*.wfm
# Voltage (2600, 1200)V: 3000 files
# E:\Pablos_Mighty_measurements\RUN1\FieldScans_sat\FieldScan_1GSsec_EL3100_Gate1700\*.wfm
# Voltage (3100, 1700)V: 3000 files
# E:\Pablos_Mighty_measurements\RUN1\FieldScans_sat\FieldScan_1GSsec_EL3600_Gate2200\*.wfm
# Voltage (3600, 2200)V: 3000 files
# E:\Pablos_Mighty_measurements\RUN1\FieldScans_sat\FieldScan_1GSsec_EL4100_Gate2700\*.wfm
# Voltage (4100, 2700)V: 3000 files

# %%
# Define voltage scan groups and their file lists
voltage_groups = {
    (2100, 700) : files21,
    (2600, 1200) : files26,
    (3100, 1700) : files31,
    (3600, 2200) : files36,
    (4100, 2700) : files41
}

s2_lowcut = 0.5e-5
s2_upcut = 1.5e-5
hist_lowcut = -5
hist_upcut = 20

# Process all voltage groups
s2_areas = {}
s2_areas_cuts = {}
for v, files in voltage_groups.items():
    print(f"Processing voltage pair {v} with {len(files)} files")
    arr = extract_s2_areas(files)
    s2_areas[v] = arr
    s2_areas_cuts[v] = apply_hist_cuts(arr, hist_lowcut, hist_upcut)
# Out:
# Processing voltage pair (2100, 700) with 2575 files
# Processing voltage pair (2600, 1200) with 3000 files
# Processing voltage pair (3100, 1700) with 3000 files
# Processing voltage pair (3600, 2200) with 3000 files
# Processing voltage pair (4100, 2700) with 3000 files

# %%
plt.figure(figsize=(8, 6))
for v, color in zip([(2100, 700), (2600, 1200), (3100, 1700), (3600, 2200)],
                              ['darkblue', 'gold', 'lime', 'magenta']):
    plt.hist(s2_areas_cuts[v], bins=150, 
             label=f"$E_{{drift}}$: {round(v[1]/1.4)} V/cm, $V_{{anode}}$: {v[0]} V", 
             alpha=0.5, color=color)

plt.gca().set(xlabel='S2 Area (mV*us)', ylabel='Counts', title='Drift field scan, EL field: 1.75 kV/cm')
plt.legend()

# %%
plt.figure(figsize=(8, 6))
for v, color in zip([(2100, 700), (3600, 2200)],
                              ['blue', 'red']):
    plt.hist(s2_areas_cuts[v], bins=150, 
             label=f"$E_{{drift}}$: {round(v[1]/1.4)} V/cm, $V_{{EL}}$: {v[0]} V", 
             alpha=0.5, color=color)

plt.gca().set(xlabel='S2 Area (mV*us)', ylabel='Counts', title='Drift field scan, EL field: 1.75 kV/cm')
plt.legend()

# %% [markdown]
# # Drift Field scan, low range:
# Vary both voltages together, then the EL field stays constant (difference of 1400 V) and the drift field increases

# %%
# Define voltage values for scan
voltage_pairs = [(2200, 800), (2150, 750), (2100, 700)]
# Build paths and file lists using a loop
base_path_el = r'E:\Pablos_Mighty_measurements\RUN1\FieldScans\FieldScan_1GSsec_EL{}_Gate{}\*.wfm'
field_files = {}
for v in voltage_pairs:
    path = base_path_el.format(str(v[0]), str(v[1]))
    print(path)
    files = sorted(glob(path))
    field_files[v] = files
    print(f"Voltage {v}V: {len(files)} files")

# For compatibility with previous cells, you can still assign:
files800 = field_files[(2200, 800)]
files750 = field_files[(2150, 750)]
files700 = field_files[(2100, 700)]
# Out:
# E:\Pablos_Mighty_measurements\RUN1\FieldScans\FieldScan_1GSsec_EL2200_Gate800\*.wfm
# Voltage (2200, 800)V: 3000 files
# E:\Pablos_Mighty_measurements\RUN1\FieldScans\FieldScan_1GSsec_EL2150_Gate750\*.wfm
# Voltage (2150, 750)V: 2997 files
# E:\Pablos_Mighty_measurements\RUN1\FieldScans\FieldScan_1GSsec_EL2100_Gate700\*.wfm
# Voltage (2100, 700)V: 3000 files

# %%
# Define voltage scan groups and their file lists
voltage_groups = {
    (2200, 800) : files800,
    (2150, 750) : files750,
    (2100, 700) : files700
}

s2_lowcut = 0.5e-5
s2_upcut = 1.5e-5
hist_lowcut = -5
hist_upcut = 20

# Process all voltage groups
s2_areas = {}
s2_areas_cuts = {}
for v, files in voltage_groups.items():
    print(f"Processing voltage pair {v} with {len(files)} files")
    arr = extract_s2_areas(files)
    s2_areas[v] = arr
    s2_areas_cuts[v] = apply_hist_cuts(arr, hist_lowcut, hist_upcut)
# Out:
# Processing voltage pair (2200, 800) with 3000 files
# Processing voltage pair (2150, 750) with 2997 files
# Processing voltage pair (2100, 700) with 3000 files

# %%
plt.figure(figsize=(8, 6))
for v, color in zip([(2100, 700), (2150, 750), (2200, 800)],
                              ['blue', 'orange', 'green']):
    plt.hist(s2_areas_cuts[v], bins=150, 
             label=f"$E_{{drift}}$: {round(v[1]/1.4)} V/cm, $V_{{anode}}$: {v[0]} V", 
             alpha=0.5, color=color)

plt.gca().set(xlabel='S2 Area (mV*us)', ylabel='Counts', title='Drift field scan, EL field: 1.75 kV/cm')
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from glob import glob
from RaTag.scripts.wfm2read_fast import wfm2read
from RaTag.scripts.wfm2spectra import get_peak_volts, histogram_voltages

# %% [markdown]
# # Reconstruct spectrum from raw waveforms (.csv)

# %%
def waveforms2channels(files):
    vmax = []
    for file in files:
        df = pd.read_csv(file, header=None, names=['time', 'voltage'], skiprows=6, )
    # df.set_index('time', inplace=True, drop=True)
        vmax.append(df['voltage'].max() - df['voltage'].min())

    channels = [v * 2048 / 10 for v in vmax]  # Convert to ADC counts
    plt.hist(channels, bins=100, range=(0, 2048), );
    plt.gca().set(xlabel='ADC Counts', ylabel='Number of Channels',)

    return channels

# %%
# ROOT_DIR = '/Users/pabloherrero/Library/CloudStorage/GoogleDrive-pablo.herrero-gomez@mail.huji.ac.il/My Drive/RaTag_data/scope_data/' 
ROOT_DIR = '/Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/'
files = glob(ROOT_DIR + '*.csv')
channels = waveforms2channels(files)

# %%
plt.hist(channels, bins=100, );
plt.gca().set(xlabel='Energy channel (arb. units)', ylabel='Counts', title='Energy channel from waveforms')
# Out:
# [Text(0.5, 0, 'Energy channel (arb. units)'),
#  Text(0, 0.5, 'Counts'),
#  Text(0.5, 1.0, 'Energy channel from waveforms')]

# %%
vmax = [c / 2048 * 10 for c in channels]  # Convert to ADC counts
plt.hist(vmax, bins=100);
plt.gca().set(xlabel='Voltage (V)', ylabel='Counts', title='Voltage from waveforms')
# Out:
# [Text(0.5, 0, 'Voltage (V)'),
#  Text(0, 0.5, 'Counts'),
#  Text(0.5, 1.0, 'Voltage from waveforms')]

# %% [markdown]
# # Reconstruct full spectrum from peak2peak measurement
#
# (much lighter, more counts)

# %% [markdown]
# ## No SCA

# %%
def peak2peak2channels(files):
    vmax = []
    for file in files:
        df = pd.read_csv(file, header=None, names=['time', 'voltage'], skiprows=6, )

        vmax.append(df['Pk-Pk'].values)

    channels = [v * 2048 / 10 for v in vmax]  # Convert to ADC counts
    plt.hist(channels, bins=100, range=(0, 2048), );
    plt.gca().set(xlabel='ADC Counts', ylabel='Number of Channels',)

    return channels

# %%
ROOT_DIR = '/Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/peak2peak/noSCA/'
files = glob(ROOT_DIR + '*.csv')
voltages = []
for file in files:
    p2p = pd.read_csv(file, header=None, names=['val', 'mean', 'min', 'max', 'std', 'count', 'info', 'units',]).iloc[2,0]
    voltages.append(p2p)

# %%
plt.hist(voltages, bins=100, range=(0, 10));
plt.gca().set(xlabel='Voltage (V)', ylabel='Counts', title='Peak-to-Peak Voltages, no SCA');

# %%
preamps = [v / get_total_gain(63, coarse_gain=50) for v in voltages]  
plt.hist(preamps, bins=100, );

# %%
def get_total_gain(dial, coarse_gain = 50):
    Gmin = 0.5
    Gmax = 1.5
    dmin = 50
    dmax = 150
    Gfine = Gmin + (Gmax - Gmin) * (dial - dmin) / (dmax - dmin)
    Gtotal = Gfine * coarse_gain
    return Gtotal

def voltage2energy(V, fine_gain = 63, coarse_gain = 50):
    """
    Convert a channel number to voltage and energy peak.
    :param V: voltage in volts
    :param fine_gain: Fine gain setting (0-63)
    :param coarse_gain: Coarse gain setting (default 50)
    :return: Tuple of voltage in mV and energy peak in eV
    """
    assert coarse_gain in [50, 100, 200, 500, 10000], "Coarse gain must be one of [50, 100, 200, 500, 10000]"

    gain_amp = get_total_gain(fine_gain, coarse_gain)
    gain_preamp = 45 # mV / MeV preamp gain

    V_mV = V * 1000 # mV

    E_peak = V_mV / (gain_amp * gain_preamp) # MeV

    # print(f"V = {V:.2f} V")
    # print(f"E_peak = {E_peak:.2f} MeV")
    return V_mV, E_peak

# %%
get_total_gain(63, 50)
# Out:
# 31.5

# %%
V = 240 # mV
c_sensitivity = 45 # mV/MeV
E = V / c_sensitivity # MeV
print(f"Voltage: {V} mV, Energy: {E:.2f} MeV")
# Out:
# Voltage: 240 mV, Energy: 5.33 MeV

# %%
E = 8.2 # MeV
c_sensitivity = 45 # mV/MeV
V_pre = E * c_sensitivity # mV
V_amp = V_pre * get_total_gain(63, 50) # mV
print(f"Voltage pre amp: {V_pre} mV, amp: {V_amp}, Energy: {E:.2f} MeV")
# Out:
# Voltage pre amp: 368.99999999999994 mV, amp: 11623.499999999998, Energy: 8.20 MeV

# %%
Vamp = V * get_total_gain(63, coarse_gain=50) 
Vamp
# Out:
# 7560.0

# %%
energies = [voltage2energy(c, fine_gain=63, coarse_gain=50)[0] for c in channels]
plt.hist(energies, bins=100, );
plt.gca().set(xlabel='Energy (eV)', ylabel='Counts', title='Energy from waveforms');

# %% [markdown]
# ## SCA 5-7 V

# %%
ROOT_DIR = '/Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/peak2peak/SCA_5-7V/'
files = sorted(glob(ROOT_DIR + '*.csv'))
voltages_sca1 = []
for file in files:
    p2p = pd.read_csv(file, header=None, names=['val', 'mean', 'min', 'max', 'std', 'count', 'info', 'units',]).iloc[2,0]
    voltages_sca1.append(p2p)

# %%
plt.hist(voltages_sca1, bins=100, range=(0, 10));
plt.gca().set(xlabel='Voltage (V)', ylabel='Counts', title='Peak-to-Peak Voltages, SCA 5-7V');

# %%
plt.hist(voltages, bins=100, range=(0, 10), label='No SCA');
plt.hist(voltages_sca1, bins=100, range=(0, 10), label='SCA 5-7V');
plt.gca().set(xlabel='Voltage (V)', ylabel='Counts', );
plt.gca().set(xlim=(5, 7), )
# Out:
# [(5.0, 7.0)]

# %% [markdown]
# ## SCA 5.6-6.0V

# %%
ROOT_DIR = '/Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/peak2peak/SCA_5.6-6.0V/'
files = sorted(glob(ROOT_DIR + '*.csv'))
voltages_sca2 = []
for file in files:
    p2p = pd.read_csv(file, header=None, names=['val', 'mean', 'min', 'max', 'std', 'count', 'info', 'units',]).iloc[2,0]
    voltages_sca2.append(p2p)

# %%
plt.hist(voltages_sca2, bins=100, range=(0, 10));
plt.gca().set(xlabel='Voltage (V)', ylabel='Counts', title='Peak-to-Peak Voltages, SCA 5.6-6.0V');

# %%
plt.hist(voltages, bins=100, range=(0, 10), label='No SCA');
plt.hist(voltages_sca1, bins=100, range=(0, 10), label='SCA 5-7V');
plt.hist(voltages_sca2, bins=100, range=(0, 10), label='SCA 5.6-6.0V');

plt.gca().set(xlabel='Voltage (V)', ylabel='Counts', );
plt.legend()
# plt.gca().set(xlim=(5, 7), )

# %% [markdown]
# # Read multiple binary files

# %% [markdown]
# ## No SCA

# %%
path = '/Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/'
filesbin = sorted(glob(path + '*.wfm'))
filesbin[:3]
# Out:
# ['/Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_100Wfm.wfm',
#  '/Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_101Wfm.wfm',
#  '/Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_102Wfm.wfm']

# %%
y, t, info, ind_over, ind_under = wfm2read(filesbin[0], step=0.001)
# Out:
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_100Wfm.wfm starting at index 0 with step 0.001

# %%
plt.plot(t, y, label='Waveform')
plt.gca().set(xlim=(0, 2e-8))#, xlabel='Time (s)', ylabel='Voltage (V)', title='Waveform from WFM file')
# Out:
# [(0.0, 2e-08)]

# %%
peak_volts = np.array([])
for file in filesbin:
    peak_volts = np.append(peak_volts, get_peak_volts(file))
# Out:
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_100Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_101Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_102Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_103Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_104Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_105Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_106Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_107Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_108Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_109Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_110Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_111Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_112Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_113Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_114Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_115Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_116Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_117Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_118Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_119Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_120Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_121Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_122Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_123Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_124Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_125Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_126Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_127Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_128Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_129Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_130Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_131Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_132Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_133Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_134Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_135Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_136Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_137Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_138Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_139Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_140Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_21Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_22Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_23Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_24Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_25Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_26Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_27Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_28Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_29Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_30Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_31Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_32Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_33Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_34Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_35Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_36Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_37Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_38Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_39Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_40Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_41Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_42Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_43Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_44Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_45Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_46Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_47Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_48Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_49Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_50Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_51Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_52Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_53Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_54Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_55Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_56Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_57Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_58Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_59Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_60Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_61Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_62Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_63Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_64Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_65Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_66Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_67Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_68Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_69Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_70Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_71Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_72Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_73Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_74Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_75Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_76Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_77Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_78Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_79Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_80Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_81Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_82Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_83Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_84Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_85Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_86Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_87Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_88Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_89Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_90Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_91Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_92Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_93Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_94Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_95Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_96Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_97Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_98Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/27052025_noSCA_99Wfm.wfm starting at index 0 with step 0.001

# %%
pathout = '/Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/noSCA/peaks_out.csv'
np.savetxt(pathout, peak_volts)

# %%
len(peak_volts)
# Out:
# 1134604

# %%
plt.hist(peak_volts, bins=250, edgecolor='black', )
plt.gca().set(xlim=(4, 6.5), xlabel='Voltage (V)', ylabel='Counts', title='Peak Voltages from Waveforms');

# %% [markdown]
# # SCA 4.62-5.82 V

# %%
path_sca = '/Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82'
files_sca = sorted(glob(path_sca + '/*.wfm'))

# %%
peaks_sca = np.array([])
for file in files_sca:
    peaks_sca = np.append(peaks_sca, get_peak_volts(file))
# Out:
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_100Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_10Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_11Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_12Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_13Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_14Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_15Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_16Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_17Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_18Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_19Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_1Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_20Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_21Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_22Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_23Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_24Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_25Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_26Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_27Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_28Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_29Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_2Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_30Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_31Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_32Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_33Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_34Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_35Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_36Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_37Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_38Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_39Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_3Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_40Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_41Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_42Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_43Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_44Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_45Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_46Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_47Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_48Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_49Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_4Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_50Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_51Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_52Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_53Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_54Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_55Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_56Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_57Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_58Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_59Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_5Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_60Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_61Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_62Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_63Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_64Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_65Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_66Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_67Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_68Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_69Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_6Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_70Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_71Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_72Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_73Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_74Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_75Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_76Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_77Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_78Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_79Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_7Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_80Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_81Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_82Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_83Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_84Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_85Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_86Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_87Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_88Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_89Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_8Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_90Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_91Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_92Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_93Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_94Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_95Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_96Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_97Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_98Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_99Wfm.wfm starting at index 0 with step 0.001
# Reading 9999999 data points from /Users/pabloherrero/sabat/RaTagging/RaTag/scope_data/waveforms/SCA_4.62-5.82/27052025_SCA_4.62-5.82_9Wfm.wfm starting at index 0 with step 0.001

# %%
plt.hist(peak_volts, bins=300, edgecolor='black', label='No SCA')
plt.hist(peaks_sca, bins=300, edgecolor='black', color='red', alpha=0.5, label='SCA 4.62-5.82V')
plt.gca().set(xlim=(4, 6.5), xlabel='Voltage (V)', ylabel='Counts', title='Peak Voltages from Waveforms');
plt.legend()
